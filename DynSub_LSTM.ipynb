# %% [markdown]
# First do an Earthquake simulation

# %%
# %cd Simple1DOF
# Out:
# /home/tomsimpson/Documents/ETHwork/DynSub/Simple1DOF

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from scipy.io import loadmat
from math import sqrt


os.getcwd()
Ag = loadmat('ElCentro.mat')
Ag = Ag['Ag']

plt.plot(Ag[:,0],Ag[:,1])

# %%
def f(y, t, params):
    y1, y2 = y
    k, c, m, knl, Ag, ts = params
    i = int(t/ts)
    ag=Ag[i,1]
    derivs=[y2,
           (-m*ag*9.81-knl*y1**3-k*y1-c*y2)/m]
    return derivs

tStop = 31.2
ts = 0.02
t = np.arange(0., tStop, ts)
nt = len(t)


np.random.seed(1)
#Parameters
k = (176.75+1224.1)*1e6
m = 1.75e6
c = 0.04*sqrt(k*m)
knl = 10e12
#knl=0
params=[k, c, m, knl, Ag, ts]

#Initial values
y1_0=0
y2_0=0
y0 = [y1_0, y2_0]

psoln = odeint(f, y0, t, args=(params,))

# %%
plt.figure(0)
plt.plot(Ag[:,0],1000*psoln[:,0])
plt.xlabel('Time s')
plt.ylabel('Displacement mm')

plt.figure(1)
plt.plot(k*psoln[:,0],label='lin')
plt.plot(knl*psoln[:,0]**3,label='nonlin')
plt.legend()

# %%
F_exp = -psoln[:,0:1]*1224.1e6
ExInps = np.concatenate((Ag[:,1:],F_exp),axis=1)
X = psoln[:,0:1]

# %%
f_train = ExInps[0:1000,:]
f_test = ExInps[:,:]

x_train = X[0:1000,:]
x_test = X[:,:]

datasetTrain = np.concatenate((f_train,x_train),axis=1)
datasetTest=np.concatenate((f_test,x_test),axis=1)

def create_dataset(dataset, look_back=6):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), :]
        X.append(a)
        Y.append(dataset[i + look_back, 2:])
    return np.array(X), np.array(Y)

f_train, x_train = create_dataset(datasetTrain)
f_test, x_test = create_dataset(datasetTest)

# %%
## One Step Ahead Prediction

f_train.shape
f_train = np.reshape(f_train,(f_train.shape[0],-1))
f_test = np.reshape(f_test,(f_test.shape[0],-1))
fmax=f_test.max(axis=0,keepdims=True)
fmin=f_test.min(axis=0,keepdims=True)
f_test_norm=2*(f_test-fmin)/(fmax-fmin)-1


xmax=x_test.max(axis=0,keepdims=True)
xmin=x_test.min(axis=0,keepdims=True)
x_test_norm=2*(x_test-xmin)/(xmax-xmin)-1

f_train_norm = f_test_norm[:1000,:]
x_train_norm = x_test_norm[:1000,:]



from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(f_train_norm, x_train_norm)
print(reg.score(f_train_norm,x_train_norm))
print(reg.score(f_test_norm,x_test_norm))

yy = reg.predict(f_test_norm)

plt.plot(yy)
plt.plot(x_test_norm,'--')

from sklearn.metrics import mean_squared_error
print(mean_squared_error(yy,x_test_norm))
# Out:
# 0.9990803598779492
# 0.9991484066099547
# 5.8337814050382205e-05

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.preprocessing import normalize





usualCallback = EarlyStopping(monitor='val_loss', min_delta=1e-10, patience = 150)
checkpoint = ModelCheckpoint('.mdl_wts.hdf5', verbose=1, monitor='val_loss',save_best_only=True, mode='auto') 
callbacks_list = [usualCallback, checkpoint]

print(f_train.shape[1])

nn = Sequential()
nn.add(Dense(22,input_dim = f_train.shape[1], activation='tanh'))
nn.add(Dense(1,activation='linear'))
nn.compile(loss='mean_squared_error', optimizer='adam')
nn.summary()
nn.load_weights('.mdl_wts.hdf5')
nn.fit(f_train_norm,x_train_norm,validation_data=(f_test_norm,x_test_norm) ,epochs=2000, batch_size=64, callbacks=callbacks_list,shuffle=False)

nn.load_weights('.mdl_wts.hdf5')
print(nn.evaluate(f_test_norm,x_test_norm))

yhat = nn.predict(f_test_norm)
plt.plot(yhat)
plt.plot(x_test_norm,'--')

print(mean_squared_error(yhat,x_test_norm))
# Out:
# Using TensorFlow backend.
# 18
# WARNING:tensorflow:From /home/tomsimpson/anaconda3/envs/AANN/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/tomsimpson/anaconda3/envs/AANN/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/tomsimpson/anaconda3/envs/AANN/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/tomsimpson/anaconda3/envs/AANN/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 22)                418
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 23
# =================================================================
# Total params: 441
# Trainable params: 441
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /home/tomsimpson/anaconda3/envs/AANN/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /home/tomsimpson/anaconda3/envs/AANN/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/tomsimpson/anaconda3/envs/AANN/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/tomsimpson/anaconda3/envs/AANN/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /home/tomsimpson/anaconda3/envs/AANN/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /home/tomsimpson/anaconda3/envs/AANN/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /home/tomsimpson/anaconda3/envs/AANN/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /home/tomsimpson/anaconda3/envs/AANN/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 1000 samples, validate on 1553 samples
# Epoch 1/2000
# 1000/1000 [==============================] - 1s 766us/step - loss: 1.4758e-05 - val_loss: 4.7147e-06
#
# Epoch 00001: val_loss improved from inf to 0.00000, saving model to .mdl_wts.hdf5
# Epoch 2/2000
# 1000/1000 [==============================] - 0s 17us/step - loss: 6.0987e-06 - val_loss: 9.0478e-06
#
# Epoch 00002: val_loss did not improve from 0.00000
# Epoch 3/2000
# 1000/1000 [==============================] - 0s 32us/step - loss: 1.0210e-05 - val_loss: 1.5791e-05
#
# Epoch 00003: val_loss did not improve from 0.00000
# Epoch 4/2000
# 1000/1000 [==============================] - 0s 32us/step - loss: 1.6943e-05 - val_loss: 4.2414e-05
#
# Epoch 00004: val_loss did not improve from 0.00000
# Epoch 5/2000
# 1000/1000 [==============================] - 0s 38us/step - loss: 3.4451e-05 - val_loss: 6.1641e-05
#
# Epoch 00005: val_loss did not improve from 0.00000
# Epoch 6/2000
# 1000/1000 [==============================] - 0s 35us/step - loss: 4.6660e-05 - val_loss: 4.5559e-05
#
# Epoch 00006: val_loss did not improve from 0.00000
# Epoch 7/2000
# 1000/1000 [==============================] - 0s 38us/step - loss: 3.0436e-05 - val_loss: 2.0195e-05
#
# Epoch 00007: val_loss did not improve from 0.00000
# Epoch 8/2000
# 1000/1000 [==============================] - 0s 54us/step - loss: 2.9694e-05 - val_loss: 9.7227e-05
#
# Epoch 00008: val_loss did not improve from 0.00000
# Epoch 9/2000
# 1000/1000 [==============================] - 0s 38us/step - loss: 1.5211e-04 - val_loss: 8.3446e-05
#
# Epoch 00009: val_loss did not improve from 0.00000
# Epoch 10/2000
# 1000/1000 [==============================] - 0s 97us/step - loss: 9.8433e-05 - val_loss: 3.3659e-05
#
# Epoch 00010: val_loss did not improve from 0.00000
# Epoch 11/2000
# 1000/1000 [==============================] - 0s 56us/step - loss: 5.9059e-05 - val_loss: 7.5591e-05
#
# Epoch 00011: val_loss did not improve from 0.00000
# Epoch 12/2000
# 1000/1000 [==============================] - 0s 111us/step - loss: 1.1471e-04 - val_loss: 1.6673e-05
#
# Epoch 00012: val_loss did not improve from 0.00000
# Epoch 13/2000
# 1000/1000 [==============================] - 0s 70us/step - loss: 1.8753e-05 - val_loss: 2.0336e-05
#
# Epoch 00013: val_loss did not improve from 0.00000
# Epoch 14/2000
# 1000/1000 [==============================] - 0s 43us/step - loss: 4.1785e-05 - val_loss: 3.9532e-05
#
# Epoch 00014: val_loss did not improve from 0.00000
# Epoch 15/2000
# 1000/1000 [==============================] - 0s 56us/step - loss: 8.1752e-05 - val_loss: 1.4827e-04
#
# Epoch 00015: val_loss did not improve from 0.00000
# Epoch 16/2000
# 1000/1000 [==============================] - 0s 64us/step - loss: 2.6363e-04 - val_loss: 1.8115e-05
#
# Epoch 00016: val_loss did not improve from 0.00000
# Epoch 17/2000
# 1000/1000 [==============================] - 0s 68us/step - loss: 6.7435e-05 - val_loss: 1.4618e-05
#
# Epoch 00017: val_loss did not improve from 0.00000
# Epoch 18/2000
# 1000/1000 [==============================] - 0s 58us/step - loss: 1.5600e-05 - val_loss: 7.7746e-06
#
# Epoch 00018: val_loss did not improve from 0.00000
# Epoch 19/2000
# 1000/1000 [==============================] - 0s 37us/step - loss: 2.0153e-05 - val_loss: 1.7560e-06
#
# Epoch 00019: val_loss improved from 0.00000 to 0.00000, saving model to .mdl_wts.hdf5
# Epoch 20/2000
# 1000/1000 [==============================] - 0s 33us/step - loss: 4.6595e-06 - val_loss: 2.2625e-06
#
# Epoch 00020: val_loss did not improve from 0.00000
# Epoch 21/2000
# 1000/1000 [==============================] - 0s 24us/step - loss: 3.2772e-06 - val_loss: 2.2212e-06
#
# Epoch 00021: val_loss did not improve from 0.00000
# Epoch 22/2000
# 1000/1000 [==============================] - 0s 20us/step - loss: 3.1376e-06 - val_loss: 1.7540e-06
#
# Epoch 00022: val_loss improved from 0.00000 to 0.00000, saving model to .mdl_wts.hdf5
# Epoch 23/2000
# 1000/1000 [==============================] - 0s 25us/step - loss: 2.4349e-06 - val_loss: 1.6014e-06
#
# Epoch 00023: val_loss improved from 0.00000 to 0.00000, saving model to .mdl_wts.hdf5
# Epoch 24/2000
# 1000/1000 [==============================] - 0s 16us/step - loss: 1.9898e-06 - val_loss: 1.5803e-06
#
# Epoch 00024: val_loss improved from 0.00000 to 0.00000, saving model to .mdl_wts.hdf5
# Epoch 25/2000
# 1000/1000 [==============================] - 0s 20us/step - loss: 2.1298e-06 - val_loss: 1.5891e-06
#
# Epoch 00025: val_loss did not improve from 0.00000
# Epoch 26/2000
# 1000/1000 [==============================] - 0s 19us/step - loss: 2.1427e-06 - val_loss: 1.6173e-06
#
# Epoch 00026: val_loss did not improve from 0.00000
# Epoch 27/2000
# 1000/1000 [==============================] - 0s 22us/step - loss: 2.1812e-06 - val_loss: 1.6533e-06
#
# Epoch 00027: val_loss did not improve from 0.00000
# Epoch 28/2000
# 1000/1000 [==============================] - 0s 20us/step - loss: 2.1610e-06 - val_loss: 1.7364e-06
#
# Epoch 00028: val_loss did not improve from 0.00000
# Epoch 29/2000
# 1000/1000 [==============================] - 0s 19us/step - loss: 2.1597e-06 - val_loss: 1.8035e-06
# Epoch 00029: val_loss did not improve from 0.00000
# Epoch 30/2000
# 1000/1000 [==============================] - 0s 25us/step - loss: 2.1918e-06 - val_loss: 1.9381e-06
#
# Epoch 00030: val_loss did not improve from 0.00000
# Epoch 31/2000
# 1000/1000 [==============================] - 0s 21us/step - loss: 2.3644e-06 - val_loss: 2.0071e-06
#
# Epoch 00031: val_loss did not improve from 0.00000
# Epoch 32/2000
# 1000/1000 [==============================] - 0s 19us/step - loss: 2.3871e-06 - val_loss: 2.0206e-06
#
# Epoch 00032: val_loss did not improve from 0.00000
# Epoch 33/2000
# 1000/1000 [==============================] - 0s 18us/step - loss: 2.2601e-06 - val_loss: 2.0193e-06
#
# Epoch 00033: val_loss did not improve from 0.00000
# Epoch 34/2000
# 1000/1000 [==============================] - 0s 20us/step - loss: 2.2187e-06 - val_loss: 2.3291e-06
#
# Epoch 00034: val_loss did not improve from 0.00000
# Epoch 35/2000
# 1000/1000 [==============================] - 0s 19us/step - loss: 2.8093e-06 - val_loss: 3.0814e-06
#
# Epoch 00035: val_loss did not improve from 0.00000
# Epoch 36/2000
# 1000/1000 [==============================] - 0s 19us/step - loss: 4.1902e-06 - val_loss: 4.1398e-06
#
# Epoch 00036: val_loss did not improve from 0.00000
# Epoch 37/2000
# 1000/1000 [==============================] - 0s 19us/step - loss: 5.8451e-06 - val_loss: 4.8327e-06
#
# Epoch 00037: val_loss did not improve from 0.00000
# Epoch 38/2000
# 1000/1000 [==============================] - 0s 21us/step - loss: 6.7001e-06 - val_loss: 4.4689e-06
#
# Epoch 00038: val_loss did not improve from 0.00000
# Epoch 39/2000
# 1000/1000 [==============================] - 0s 23us/step - loss: 5.7610e-06 - val_loss: 3.0466e-06
#
# Epoch 00039: val_loss did not improve from 0.00000
# Epoch 40/2000
# 1000/1000 [==============================] - 0s 20us/step - loss: 3.8561e-06 - val_loss: 3.3828e-06
#
# Epoch 00040: val_loss did not improve from 0.00000
# Epoch 41/2000
# 1000/1000 [==============================] - 0s 18us/step - loss: 6.3942e-06 - val_loss: 1.3545e-05
#
# Epoch 00041: val_loss did not improve from 0.00000
# Epoch 42/2000
# 1000/1000 [==============================] - 0s 19us/step - loss: 2.5517e-05 - val_loss: 4.7461e-05
#
# Epoch 00042: val_loss did not improve from 0.00000
# Epoch 43/2000
# 1000/1000 [==============================] - 0s 21us/step - loss: 7.9057e-05 - val_loss: 1.0153e-04
#
# Epoch 00043: val_loss did not improve from 0.00000
# Epoch 44/2000
# 1000/1000 [==============================] - 0s 23us/step - loss: 1.5897e-04 - val_loss: 1.0069e-04
#
# Epoch 00044: val_loss did not improve from 0.00000
# Epoch 45/2000
# 1000/1000 [==============================] - 0s 22us/step - loss: 1.5159e-04 - val_loss: 4.4835e-05
#
# Epoch 00045: val_loss did not improve from 0.00000
# Epoch 46/2000
# 1000/1000 [==============================] - 0s 22us/step - loss: 5.1502e-05 - val_loss: 5.9061e-05
#
# Epoch 00046: val_loss did not improve from 0.00000
# Epoch 47/2000
# 1000/1000 [==============================] - 0s 35us/step - loss: 1.0088e-04 - val_loss: 1.1649e-04
#
# Epoch 00047: val_loss did not improve from 0.00000
# Epoch 48/2000
# 1000/1000 [==============================] - 0s 31us/step - loss: 2.5546e-04 - val_loss: 4.0283e-05
#
# Epoch 00048: val_loss did not improve from 0.00000
# Epoch 49/2000
# 1000/1000 [==============================] - 0s 35us/step - loss: 1.0456e-04 - val_loss: 2.0815e-05
#
# Epoch 00049: val_loss did not improve from 0.00000
# Epoch 50/2000
# 1000/1000 [==============================] - 0s 43us/step - loss: 2.8921e-05 - val_loss: 2.3651e-05
#
# Epoch 00050: val_loss did not improve from 0.00000
# Epoch 51/2000
# 1000/1000 [==============================] - 0s 36us/step - loss: 5.6037e-05 - val_loss: 1.0769e-05
#
# Epoch 00051: val_loss did not improve from 0.00000
# Epoch 52/2000
# 1000/1000 [==============================] - 0s 40us/step - loss: 2.9380e-05 - val_loss: 1.3722e-05
#
# Epoch 00052: val_loss did not improve from 0.00000
# Epoch 53/2000
# 1000/1000 [==============================] - 0s 27us/step - loss: 2.1700e-05 - val_loss: 9.5895e-06
#
# Epoch 00053: val_loss did not improve from 0.00000
# Epoch 54/2000
# 1000/1000 [==============================] - 0s 35us/step - loss: 1.1331e-05 - val_loss: 2.9945e-06
#
# Epoch 00054: val_loss did not improve from 0.00000
# Epoch 55/2000
# 1000/1000 [==============================] - 0s 21us/step - loss: 5.2449e-06 - val_loss: 1.1225e-05
#
# Epoch 00055: val_loss did not improve from 0.00000
# Epoch 56/2000
# 1000/1000 [==============================] - 0s 23us/step - loss: 2.4339e-05 - val_loss: 2.2576e-05
#
# Epoch 00056: val_loss did not improve from 0.00000
# Epoch 57/2000
# 1000/1000 [==============================] - 0s 25us/step - loss: 3.5909e-05 - val_loss: 1.0461e-05
#
# Epoch 00057: val_loss did not improve from 0.00000
# Epoch 58/2000
# 1000/1000 [==============================] - 0s 22us/step - loss: 1.2560e-05 - val_loss: 6.5472e-06
#
# Epoch 00058: val_loss did not improve from 0.00000
# Epoch 59/2000
# 1000/1000 [==============================] - 0s 21us/step - loss: 1.6970e-05 - val_loss: 3.0311e-05
#
# Epoch 00059: val_loss did not improve from 0.00000
# Epoch 60/2000
# 1000/1000 [==============================] - 0s 25us/step - loss: 5.7595e-05 - val_loss: 3.4744e-05
#
# Epoch 00060: val_loss did not improve from 0.00000
# Epoch 61/2000
# 1000/1000 [==============================] - 0s 20us/step - loss: 4.9198e-05 - val_loss: 9.1639e-06
#
# Epoch 00061: val_loss did not improve from 0.00000
# Epoch 62/2000
# 1000/1000 [==============================] - 0s 18us/step - loss: 8.5243e-06 - val_loss: 1.4705e-05
#
# Epoch 00062: val_loss did not improve from 0.00000
# Epoch 63/2000
# 1000/1000 [==============================] - 0s 22us/step - loss: 3.7094e-05 - val_loss: 4.4357e-05
#
# Epoch 00063: val_loss did not improve from 0.00000
# Epoch 64/2000
# 1000/1000 [==============================] - 0s 24us/step - loss: 7.9080e-05 - val_loss: 1.8568e-05
#
# Epoch 00064: val_loss did not improve from 0.00000
# Epoch 65/2000
# 1000/1000 [==============================] - 0s 26us/step - loss: 2.5014e-05 - val_loss: 1.1193e-05
#
# Epoch 00065: val_loss did not improve from 0.00000
# Epoch 66/2000
# 1000/1000 [==============================] - 0s 42us/step - loss: 2.9158e-05 - val_loss: 4.1191e-05
#
# Epoch 00066: val_loss did not improve from 0.00000
# Epoch 67/2000
# 1000/1000 [==============================] - 0s 38us/step - loss: 8.1120e-05 - val_loss: 2.3550e-05
#
# Epoch 00067: val_loss did not improve from 0.00000
# Epoch 68/2000
# 1000/1000 [==============================] - 0s 36us/step - loss: 3.5917e-05 - val_loss: 4.4540e-06
#
# Epoch 00068: val_loss did not improve from 0.00000
# Epoch 69/2000
# 1000/1000 [==============================] - 0s 32us/step - loss: 8.9907e-06 - val_loss: 2.3474e-05
#
# Epoch 00069: val_loss did not improve from 0.00000
# Epoch 70/2000
# 1000/1000 [==============================] - 0s 34us/step - loss: 5.1528e-05 - val_loss: 2.1547e-05
#
# Epoch 00070: val_loss did not improve from 0.00000
# Epoch 71/2000
# 1000/1000 [==============================] - 0s 30us/step - loss: 3.6826e-05 - val_loss: 3.5504e-06
#
# Epoch 00071: val_loss did not improve from 0.00000
# Epoch 72/2000
# 1000/1000 [==============================] - 0s 36us/step - loss: 7.9816e-06 - val_loss: 1.7607e-05
#
# Epoch 00072: val_loss did not improve from 0.00000
# Epoch 73/2000
# 1000/1000 [==============================] - 0s 31us/step - loss: 3.7985e-05 - val_loss: 1.7407e-05
#
# Epoch 00073: val_loss did not improve from 0.00000
# Epoch 74/2000
# 1000/1000 [==============================] - 0s 20us/step - loss: 3.0445e-05 - val_loss: 3.9518e-06
#
# Epoch 00074: val_loss did not improve from 0.00000
# Epoch 75/2000
# 1000/1000 [==============================] - 0s 28us/step - loss: 4.9448e-06 - val_loss: 8.4779e-06
#
# Epoch 00075: val_loss did not improve from 0.00000
# Epoch 76/2000
# 1000/1000 [==============================] - 0s 28us/step - loss: 1.9313e-05 - val_loss: 1.3839e-05
#
# Epoch 00076: val_loss did not improve from 0.00000
# Epoch 77/2000
# 1000/1000 [==============================] - 0s 23us/step - loss: 2.5916e-05 - val_loss: 4.4866e-06
#
# Epoch 00077: val_loss did not improve from 0.00000
# Epoch 78/2000
# 1000/1000 [==============================] - 0s 21us/step - loss: 7.0746e-06 - val_loss: 6.2142e-06
#
# Epoch 00078: val_loss did not improve from 0.00000
# Epoch 79/2000
# 1000/1000 [==============================] - 0s 19us/step - loss: 1.4205e-05 - val_loss: 1.2411e-05
#
# Epoch 00079: val_loss did not improve from 0.00000
# Epoch 80/2000
# 1000/1000 [==============================] - 0s 24us/step - loss: 2.3193e-05 - val_loss: 6.2036e-06
#
# Epoch 00080: val_loss did not improve from 0.00000
# Epoch 81/2000
# 1000/1000 [==============================] - 0s 26us/step - loss: 8.2140e-06 - val_loss: 3.2908e-06
#
# Epoch 00081: val_loss did not improve from 0.00000
# Epoch 82/2000
# 1000/1000 [==============================] - 0s 21us/step - loss: 6.3879e-06 - val_loss: 9.9234e-06
#
# Epoch 00082: val_loss did not improve from 0.00000
# Epoch 83/2000
# 1000/1000 [==============================] - 0s 25us/step - loss: 1.9930e-05 - val_loss: 8.6800e-06
#
# Epoch 00083: val_loss did not improve from 0.00000
# Epoch 84/2000
# 1000/1000 [==============================] - 0s 33us/step - loss: 1.3767e-05 - val_loss: 2.6350e-06
#
# Epoch 00084: val_loss did not improve from 0.00000
# Epoch 85/2000
# 1000/1000 [==============================] - 0s 36us/step - loss: 4.5129e-06 - val_loss: 8.1138e-06
#
# Epoch 00085: val_loss did not improve from 0.00000
# Epoch 86/2000
# 1000/1000 [==============================] - 0s 38us/step - loss: 1.6207e-05 - val_loss: 1.2055e-05
#
# Epoch 00086: val_loss did not improve from 0.00000
# Epoch 87/2000
# 1000/1000 [==============================] - 0s 38us/step - loss: 1.9065e-05 - val_loss: 5.7679e-06
#
# Epoch 00087: val_loss did not improve from 0.00000
# Epoch 88/2000
# 1000/1000 [==============================] - 0s 35us/step - loss: 7.4537e-06 - val_loss: 5.8855e-06
#
# Epoch 00088: val_loss did not improve from 0.00000
# Epoch 89/2000
# 1000/1000 [==============================] - 0s 35us/step - loss: 1.2930e-05 - val_loss: 1.4166e-05
#
# Epoch 00089: val_loss did not improve from 0.00000
# Epoch 90/2000
# 1000/1000 [==============================] - 0s 34us/step - loss: 2.4880e-05 - val_loss: 9.3501e-06
#
# Epoch 00090: val_loss did not improve from 0.00000
# Epoch 91/2000
# 1000/1000 [==============================] - 0s 37us/step - loss: 1.2381e-05 - val_loss: 4.9972e-06
#
# Epoch 00091: val_loss did not improve from 0.00000
# Epoch 92/2000
# 1000/1000 [==============================] - 0s 28us/step - loss: 1.2176e-05 - val_loss: 2.2488e-05
#
# Epoch 00092: val_loss did not improve from 0.00000
# Epoch 93/2000
# 1000/1000 [==============================] - 0s 24us/step - loss: 4.4070e-05 - val_loss: 3.5873e-05
#
# Epoch 00093: val_loss did not improve from 0.00000
# Epoch 94/2000
# 1000/1000 [==============================] - 0s 22us/step - loss: 5.5265e-05 - val_loss: 2.7587e-05
#
# Epoch 00094: val_loss did not improve from 0.00000
# Epoch 95/2000
# 1000/1000 [==============================] - 0s 23us/step - loss: 3.7362e-05 - val_loss: 2.1466e-05
#
# Epoch 00095: val_loss did not improve from 0.00000
# Epoch 96/2000
# 1000/1000 [==============================] - 0s 18us/step - loss: 3.4904e-05 - val_loss: 2.6328e-05
#
# Epoch 00096: val_loss did not improve from 0.00000
# Epoch 97/2000
# 1000/1000 [==============================] - 0s 24us/step - loss: 4.4011e-05 - val_loss: 2.8452e-05
#
# Epoch 00097: val_loss did not improve from 0.00000
# Epoch 98/2000
# 1000/1000 [==============================] - 0s 20us/step - loss: 4.8967e-05 - val_loss: 5.5958e-05
#
# Epoch 00098: val_loss did not improve from 0.00000
# Epoch 99/2000
# 1000/1000 [==============================] - 0s 24us/step - loss: 1.1464e-04 - val_loss: 8.4707e-05
#
# Epoch 00099: val_loss did not improve from 0.00000
# Epoch 100/2000
# 1000/1000 [==============================] - 0s 23us/step - loss: 1.6846e-04 - val_loss: 2.8097e-05
#
# Epoch 00100: val_loss did not improve from 0.00000
# Epoch 101/2000
# 1000/1000 [==============================] - 0s 25us/step - loss: 5.7346e-05 - val_loss: 2.0186e-05
#
# Epoch 00101: val_loss did not improve from 0.00000
# Epoch 102/2000
# 1000/1000 [==============================] - 0s 40us/step - loss: 4.2094e-05 - val_loss: 6.7488e-05
#
# Epoch 00102: val_loss did not improve from 0.00000
# Epoch 103/2000
# 1000/1000 [==============================] - 0s 32us/step - loss: 1.5208e-04 - val_loss: 4.5685e-05
#
# Epoch 00103: val_loss did not improve from 0.00000
# Epoch 104/2000
# 1000/1000 [==============================] - 0s 36us/step - loss: 1.1508e-04 - val_loss: 7.8944e-06
#
# Epoch 00104: val_loss did not improve from 0.00000
# Epoch 105/2000
# 1000/1000 [==============================] - 0s 34us/step - loss: 1.9260e-05 - val_loss: 1.2710e-05
#
# Epoch 00105: val_loss did not improve from 0.00000
# Epoch 106/2000
# 1000/1000 [==============================] - 0s 39us/step - loss: 2.0539e-05 - val_loss: 1.4794e-05
#
# Epoch 00106: val_loss did not improve from 0.00000
# Epoch 107/2000
# 1000/1000 [==============================] - 0s 34us/step - loss: 3.5649e-05 - val_loss: 1.1416e-05
#
# Epoch 00107: val_loss did not improve from 0.00000
# Epoch 108/2000
# 1000/1000 [==============================] - 0s 32us/step - loss: 2.9120e-05 - val_loss: 6.3500e-06
#
# Epoch 00108: val_loss did not improve from 0.00000
# Epoch 109/2000
# 1000/1000 [==============================] - 0s 28us/step - loss: 1.1608e-05 - val_loss: 3.7200e-06
#
# Epoch 00109: val_loss did not improve from 0.00000
# Epoch 110/2000
# 1000/1000 [==============================] - 0s 24us/step - loss: 7.3281e-06 - val_loss: 9.2572e-06
#
# Epoch 00110: val_loss did not improve from 0.00000
# Epoch 111/2000
# 1000/1000 [==============================] - 0s 24us/step - loss: 2.0225e-05 - val_loss: 1.1895e-05
#
# Epoch 00111: val_loss did not improve from 0.00000
# Epoch 112/2000
# 1000/1000 [==============================] - 0s 26us/step - loss: 2.1421e-05 - val_loss: 5.9988e-06
#
# Epoch 00112: val_loss did not improve from 0.00000
# Epoch 113/2000
# 1000/1000 [==============================] - 0s 19us/step - loss: 7.4776e-06 - val_loss: 3.2137e-06
#
# Epoch 00113: val_loss did not improve from 0.00000
# Epoch 114/2000
# 1000/1000 [==============================] - 0s 20us/step - loss: 5.5441e-06 - val_loss: 9.8080e-06
#
# Epoch 00114: val_loss did not improve from 0.00000
# Epoch 115/2000
# 1000/1000 [==============================] - 0s 22us/step - loss: 2.0301e-05 - val_loss: 1.2446e-05
#
# Epoch 00115: val_loss did not improve from 0.00000
# Epoch 116/2000
# 1000/1000 [==============================] - 0s 22us/step - loss: 2.2451e-05 - val_loss: 4.9093e-06
#
# Epoch 00116: val_loss did not improve from 0.00000
# Epoch 117/2000
# 1000/1000 [==============================] - 0s 20us/step - loss: 9.6217e-06 - val_loss: 6.3944e-06
#
# Epoch 00117: val_loss did not improve from 0.00000
# Epoch 118/2000
# 1000/1000 [==============================] - 0s 23us/step - loss: 1.4892e-05 - val_loss: 1.5362e-05
#
# Epoch 00118: val_loss did not improve from 0.00000
# Epoch 119/2000
# 1000/1000 [==============================] - 0s 23us/step - loss: 2.7855e-05 - val_loss: 1.4544e-05
#
# Epoch 00119: val_loss did not improve from 0.00000
# Epoch 120/2000
# 1000/1000 [==============================] - 0s 20us/step - loss: 2.2644e-05 - val_loss: 7.5474e-06
#
# Epoch 00120: val_loss did not improve from 0.00000
# Epoch 121/2000
# 1000/1000 [==============================] - 0s 21us/step - loss: 1.2762e-05 - val_loss: 8.6874e-06
#
# Epoch 00121: val_loss did not improve from 0.00000
# Epoch 122/2000
# 1000/1000 [==============================] - 0s 25us/step - loss: 1.7953e-05 - val_loss: 1.6603e-05
#
# Epoch 00122: val_loss did not improve from 0.00000
# Epoch 123/2000
# 1000/1000 [==============================] - 0s 26us/step - loss: 2.9108e-05 - val_loss: 1.5330e-05
#
# Epoch 00123: val_loss did not improve from 0.00000
# Epoch 124/2000
# 1000/1000 [==============================] - 0s 33us/step - loss: 2.7391e-05 - val_loss: 1.0024e-05
#
# Epoch 00124: val_loss did not improve from 0.00000
# Epoch 125/2000
# 1000/1000 [==============================] - 0s 35us/step - loss: 2.4486e-05 - val_loss: 1.5490e-05
#
# Epoch 00125: val_loss did not improve from 0.00000
# Epoch 126/2000
# 1000/1000 [==============================] - 0s 33us/step - loss: 3.2009e-05 - val_loss: 2.1140e-05
#
# Epoch 00126: val_loss did not improve from 0.00000
# Epoch 127/2000
# 1000/1000 [==============================] - 0s 40us/step - loss: 3.4579e-05 - val_loss: 1.9273e-05
#
# Epoch 00127: val_loss did not improve from 0.00000
# Epoch 128/2000
# 1000/1000 [==============================] - 0s 40us/step - loss: 3.3961e-05 - val_loss: 1.7590e-05
#
# Epoch 00128: val_loss did not improve from 0.00000
# Epoch 129/2000
# 1000/1000 [==============================] - 0s 28us/step - loss: 3.7157e-05 - val_loss: 1.6985e-05
#
# Epoch 00129: val_loss did not improve from 0.00000
# Epoch 130/2000
# 1000/1000 [==============================] - 0s 29us/step - loss: 3.1136e-05 - val_loss: 1.5491e-05
#
# Epoch 00130: val_loss did not improve from 0.00000
# Epoch 131/2000
# 1000/1000 [==============================] - 0s 31us/step - loss: 2.4942e-05 - val_loss: 1.9315e-05
#
# Epoch 00131: val_loss did not improve from 0.00000
# Epoch 132/2000
# 1000/1000 [==============================] - 0s 35us/step - loss: 4.1795e-05 - val_loss: 2.2154e-05
#
# Epoch 00132: val_loss did not improve from 0.00000
# Epoch 133/2000
# 1000/1000 [==============================] - 0s 39us/step - loss: 5.1338e-05 - val_loss: 1.5495e-05
#
# Epoch 00133: val_loss did not improve from 0.00000
# Epoch 134/2000
# 1000/1000 [==============================] - 0s 30us/step - loss: 2.9573e-05 - val_loss: 1.4323e-05
#
# Epoch 00134: val_loss did not improve from 0.00000
# Epoch 135/2000
# 1000/1000 [==============================] - 0s 21us/step - loss: 2.4073e-05 - val_loss: 2.2572e-05
#
# Epoch 00135: val_loss did not improve from 0.00000
# Epoch 136/2000
# 1000/1000 [==============================] - 0s 25us/step - loss: 4.7717e-05 - val_loss: 2.1566e-05
#
# Epoch 00136: val_loss did not improve from 0.00000
# Epoch 137/2000
# 1000/1000 [==============================] - 0s 25us/step - loss: 4.6202e-05 - val_loss: 8.4685e-06
#
# Epoch 00137: val_loss did not improve from 0.00000
# Epoch 138/2000
# 1000/1000 [==============================] - 0s 21us/step - loss: 1.4333e-05 - val_loss: 8.7173e-06
#
# Epoch 00138: val_loss did not improve from 0.00000
# Epoch 139/2000
# 1000/1000 [==============================] - 0s 24us/step - loss: 1.6565e-05 - val_loss: 2.0004e-05
#
# Epoch 00139: val_loss did not improve from 0.00000
# Epoch 140/2000
# 1000/1000 [==============================] - 0s 21us/step - loss: 4.5057e-05 - val_loss: 1.5285e-05
#
# Epoch 00140: val_loss did not improve from 0.00000
# Epoch 141/2000
# 1000/1000 [==============================] - 0s 24us/step - loss: 3.5342e-05 - val_loss: 3.5471e-06
#
# Epoch 00141: val_loss did not improve from 0.00000
# Epoch 142/2000
# 1000/1000 [==============================] - 0s 23us/step - loss: 7.4841e-06 - val_loss: 7.8180e-06
#
# Epoch 00142: val_loss did not improve from 0.00000
# Epoch 143/2000
# 1000/1000 [==============================] - 0s 25us/step - loss: 1.5849e-05 - val_loss: 1.6365e-05
#
# Epoch 00143: val_loss did not improve from 0.00000
# Epoch 144/2000
# 1000/1000 [==============================] - 0s 26us/step - loss: 3.5613e-05 - val_loss: 1.2961e-05
#
# Epoch 00144: val_loss did not improve from 0.00000
# Epoch 145/2000
# 1000/1000 [==============================] - 0s 34us/step - loss: 2.7044e-05 - val_loss: 5.1675e-06
#
# Epoch 00145: val_loss did not improve from 0.00000
# Epoch 146/2000
# 1000/1000 [==============================] - 0s 36us/step - loss: 7.1033e-06 - val_loss: 5.4273e-06
#
# Epoch 00146: val_loss did not improve from 0.00000
# Epoch 147/2000
# 1000/1000 [==============================] - 0s 42us/step - loss: 8.0104e-06 - val_loss: 1.2910e-05
#
# Epoch 00147: val_loss did not improve from 0.00000
# Epoch 148/2000
# 1000/1000 [==============================] - 0s 59us/step - loss: 2.7971e-05 - val_loss: 1.8381e-05
#
# Epoch 00148: val_loss did not improve from 0.00000
# Epoch 149/2000
# 1000/1000 [==============================] - 0s 39us/step - loss: 3.8747e-05 - val_loss: 1.2820e-05
#
# Epoch 00149: val_loss did not improve from 0.00000
# Epoch 150/2000
# 1000/1000 [==============================] - 0s 36us/step - loss: 2.1936e-05 - val_loss: 5.4500e-06
#
# Epoch 00150: val_loss did not improve from 0.00000
# Epoch 151/2000
# 1000/1000 [==============================] - 0s 23us/step - loss: 8.5371e-06 - val_loss: 1.3533e-05
#
# Epoch 00151: val_loss did not improve from 0.00000
# Epoch 152/2000
# 1000/1000 [==============================] - 0s 26us/step - loss: 3.2172e-05 - val_loss: 3.3887e-05
#
# Epoch 00152: val_loss did not improve from 0.00000
# Epoch 153/2000
# 1000/1000 [==============================] - 0s 27us/step - loss: 6.6746e-05 - val_loss: 3.8744e-05
#
# Epoch 00153: val_loss did not improve from 0.00000
# Epoch 154/2000
# 1000/1000 [==============================] - 0s 24us/step - loss: 5.9786e-05 - val_loss: 1.9154e-05
#
# Epoch 00154: val_loss did not improve from 0.00000
# Epoch 155/2000
# 1000/1000 [==============================] - 0s 26us/step - loss: 1.8825e-05 - val_loss: 8.6043e-06
#
# Epoch 00155: val_loss did not improve from 0.00000
# Epoch 156/2000
# 1000/1000 [==============================] - 0s 26us/step - loss: 1.7074e-05 - val_loss: 4.1231e-05
#
# Epoch 00156: val_loss did not improve from 0.00000
# Epoch 157/2000
# 1000/1000 [==============================] - 0s 32us/step - loss: 8.6340e-05 - val_loss: 5.8522e-05
#
# Epoch 00157: val_loss did not improve from 0.00000
# Epoch 158/2000
# 1000/1000 [==============================] - 0s 27us/step - loss: 9.4481e-05 - val_loss: 1.2294e-05
#
# Epoch 00158: val_loss did not improve from 0.00000
# Epoch 159/2000
# 1000/1000 [==============================] - 0s 25us/step - loss: 2.1861e-05 - val_loss: 3.4967e-05
#
# Epoch 00159: val_loss did not improve from 0.00000
# Epoch 160/2000
# 1000/1000 [==============================] - 0s 27us/step - loss: 8.3028e-05 - val_loss: 7.1993e-05
#
# Epoch 00160: val_loss did not improve from 0.00000
# Epoch 161/2000
# 1000/1000 [==============================] - 0s 29us/step - loss: 1.3303e-04 - val_loss: 2.9391e-05
#
# Epoch 00161: val_loss did not improve from 0.00000
# Epoch 162/2000
# 1000/1000 [==============================] - 0s 26us/step - loss: 4.7600e-05 - val_loss: 1.3339e-05
#
# Epoch 00162: val_loss did not improve from 0.00000
# Epoch 163/2000
# 1000/1000 [==============================] - 0s 27us/step - loss: 3.3158e-05 - val_loss: 4.5571e-05
#
# Epoch 00163: val_loss did not improve from 0.00000
# Epoch 164/2000
# 1000/1000 [==============================] - 0s 23us/step - loss: 9.0546e-05 - val_loss: 2.5804e-05
#
# Epoch 00164: val_loss did not improve from 0.00000
# Epoch 165/2000
# 1000/1000 [==============================] - 0s 26us/step - loss: 4.1710e-05 - val_loss: 1.1855e-05
#
# Epoch 00165: val_loss did not improve from 0.00000
# Epoch 166/2000
# 1000/1000 [==============================] - 0s 27us/step - loss: 3.1371e-05 - val_loss: 3.6003e-05
#
# Epoch 00166: val_loss did not improve from 0.00000
# Epoch 167/2000
# 1000/1000 [==============================] - 0s 26us/step - loss: 7.5019e-05 - val_loss: 1.5577e-05
#
# Epoch 00167: val_loss did not improve from 0.00000
# Epoch 168/2000
# 1000/1000 [==============================] - 0s 24us/step - loss: 2.7078e-05 - val_loss: 5.3598e-06
#
# Epoch 00168: val_loss did not improve from 0.00000
# Epoch 169/2000
# 1000/1000 [==============================] - 0s 28us/step - loss: 1.1612e-05 - val_loss: 1.8146e-05
#
# Epoch 00169: val_loss did not improve from 0.00000
# Epoch 170/2000
# 1000/1000 [==============================] - 0s 21us/step - loss: 3.8881e-05 - val_loss: 1.0494e-05
#
# Epoch 00170: val_loss did not improve from 0.00000
# Epoch 171/2000
# 1000/1000 [==============================] - 0s 23us/step - loss: 1.9030e-05 - val_loss: 3.2617e-06
#
# Epoch 00171: val_loss did not improve from 0.00000
# Epoch 172/2000
# 1000/1000 [==============================] - 0s 23us/step - loss: 6.9442e-06 - val_loss: 1.1090e-05
#
# Epoch 00172: val_loss did not improve from 0.00000
# Epoch 173/2000
# 1000/1000 [==============================] - 0s 22us/step - loss: 2.2439e-05 - val_loss: 7.6888e-06
#
# Epoch 00173: val_loss did not improve from 0.00000
# Epoch 174/2000
# 1000/1000 [==============================] - 0s 21us/step - loss: 1.3272e-05 - val_loss: 2.3041e-06
#
# Epoch 00174: val_loss did not improve from 0.00000
# 1553/1553 [==============================] - 0s 15us/step
# 1.580274238379436e-06
# 1.5802746275853041e-06

# %%
# %matplotlib inline
import mpld3
mpld3.enable_notebook()
yhat = nn.predict(f_train_norm)
plt.plot(yhat)
plt.plot(x_train_norm)

# %%
### Simulation with "Hybrid Test" i.e. at each time point the input given is the AR input + ground acceleration
### along with the exogenous forcing which is calculated from the "Physical System"

# %matplotlib inline
import mpld3
mpld3.enable_notebook()


'''
def sim_pred(mdl, AG, X0, steps):
    Xhat = X0
    y = []
    Xstore = []
    for i in range(steps):
        #print(Xhat)
        Yhat = mdl.predict(Xhat)
        #RestForce = -Yhat*1224.1e6
        RestForce  = -Yhat
        #print(Yhat)
        y.append(Yhat)
        Xstore.append(Xhat)
        Xhat = Xhat[:,-3:]
        Xhat = np.concatenate((Xhat,AG[i+2:i+3,0:]),axis=1)
        Xhat = np.concatenate((Xhat,RestForce),axis=1)
        Xhat = np.concatenate((Xhat,Yhat),axis=1)   
        #print(Xhat.shape)
    
    
    return(y, Xstore)
'''

def sim_pred(mdl, AG, X0, steps):
    Xhat = X0
    y = []
    Xstore = []
    for i in range(steps):
        #print(Xhat)
        Yhat = mdl.predict(Xhat)
        #RestForce = -Yhat*1224.1e6
        RestForce  = -Yhat
        #print(Yhat)
        y.append(Yhat)
        Xstore.append(Xhat)
        Xhat = Xhat[:,-15:]
        Xhat = np.concatenate((Xhat,AG[i+2:i+3,0:]),axis=1)
        Xhat = np.concatenate((Xhat,RestForce),axis=1)
        Xhat = np.concatenate((Xhat,Yhat),axis=1)   
        #print(Xhat.shape)
    
    
    return(y, Xstore)
    
#nn.load_weights('notbad.hdf5')
nn.load_weights('.mdl_wts.hdf5')
    
(y, Xstore)= sim_pred(nn, f_test_norm[:,0:1], f_train_norm[0:1,:], 1500)

Xstore = np.asarray(Xstore)
Xstore.shape
Xstore[0]

y = np.asarray(np.squeeze(y))
plt.plot(y[4:])
plt.plot(x_test_norm[:1498],'--')


print(mean_squared_error(y[4:],x_test_norm[:1496]))

nn.save_weights('notbad.hdf5')
# Out:
# 0.0077755100471964085

# %%
X0 = f_train[0:1,:]
#print(X0)
#print(Xstore[0])
print(f_train[1:2,:])
print(Xstore[1])
print(Ag.shape)
# Out:
# [[ 3.64000000e-03  1.46206320e+04 -1.19439849e-05  9.90000000e-04
#    4.73670625e+04 -3.86954191e-05]]
# [[ 0.04489558  0.0420696  -0.0420696   0.03630855  0.04611788 -0.04611788]]
# (1560, 2)

# %%
'''
X0 = f_train[0:1,:]
print(X0)
print(Xstore[0])
'''
print(f_train[1:2,:])
print(Xstore[1])

plt.plot(Ag[:,1])
#plt.plot(f_test[:,1])
plt.plot(f_test[:,0],'--')
print(mean_squared_error(f_test[:1000,0],Ag[:1000,1]))
print(f_train_norm[0:1,:])
# Out:
# [[ 3.64000000e-03  1.46206320e+04 -1.19439849e-05  9.90000000e-04
#    4.73670625e+04 -3.86954191e-05]]
# [[ 3.64000000e-03  1.46206324e+04 -1.19439853e-05  9.90000000e-04
#    1.89547200e+06 -1.54846173e-03]]
# 0.0
# [[ 0.05351501  0.04055207 -0.04055207  0.04489558  0.0420711  -0.0420711 ]]

# %%
X0 = f_train_norm[0:1,:]
yhat1 = nn.predict(X0)
print(yhat1)
print(x_train_norm[0])

X1 = f_train_norm[1:2,:]
print(X1)
X1hat = X1
X1hat[0,-1] = yhat1
X1hat[0,-2] = -yhat1
print(X1hat)

yhat2 = nn.predict(X1hat)
print(yhat2)
print(x_train_norm[1])

X2hat = f_train_norm[2:3,:]
X2hat[0,-1] = yhat2
X2hat[0, -2] = -yhat2

yhat3 = nn.predict(X2hat)
print(yhat3)
print(x_train_norm[2])
# Out:
# [[-0.04548717]]
# [-0.04547331]
# [[ 0.04489558  0.0420711  -0.0420711   0.03630855  0.04548717 -0.04548717]]
# [[ 0.04489558  0.0420711  -0.0420711   0.03630855  0.04548717 -0.04548717]]
# [[-0.04848266]]
# [-0.048392]
# [[-0.05038805]]
# [-0.0500974]
